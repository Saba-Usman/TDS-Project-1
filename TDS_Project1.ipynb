# %%
import requests
import csv

GITHUB_TOKEN = "secrettoken"
HEADERS = {"Authorization": f"token {GITHUB_TOKEN}"}

def get_users_in_basel():
    users = []
    query = "location:Mumbai+followers:>50"
    page = 1
    per_page = 100
    total_users = 0

    while True:
        url = f"https://api.github.com/search/users?q={query}&per_page={per_page}&page={page}"
        response = requests.get(url, headers=HEADERS)
        print(f"Fetching page {page}...")

        if response.status_code != 200:
            print("Error fetching data:", response.json())
            break

        data = response.json()
        users.extend(data['items'])
        total_users += len(data['items'])

        if len(data['items']) < per_page:
            break

        page += 1

    detailed_users = []
    for user in users:
        user_info = get_user_details(user['login'])
        detailed_users.append(user_info)

    return detailed_users

def get_user_details(username):
    user_url = f"https://api.github.com/users/{username}"
    user_data = requests.get(user_url, headers=HEADERS).json()

    return {
        'login': user_data['login'],
        'name': user_data['name'],
        'company': clean_company_name(user_data['company']),
        'location': user_data['location'],
        'email': user_data['email'],
        'hireable': user_data['hireable'],
        'bio': user_data['bio'],
        'public_repos': user_data['public_repos'],
        'followers': user_data['followers'],
        'following': user_data['following'],
        'created_at': user_data['created_at'],
    }

def clean_company_name(company):
    if company:
        company = company.strip().upper()
        if company.startswith('@'):
            company = company[1:]
    return company

def get_user_repos(username):
    repos_url = f"https://api.github.com/users/{username}/repos?per_page=500"
    response = requests.get(repos_url, headers=HEADERS)
    repos_data = response.json()

    repos = []
    for repo in repos_data:
        repos.append({
            'login': username,
            'full_name': repo['full_name'],
            'created_at': repo['created_at'],
            'stargazers_count': repo['stargazers_count'],
            'watchers_count': repo['watchers_count'],
            'language': repo['language'],
            'has_projects': repo['has_projects'],
            'has_wiki': repo['has_wiki'],
            'license_name': repo['license']['key'] if repo['license'] else None,
        })

    return repos

def save_users_to_csv(users):
    with open('users.csv', mode='w', newline='') as file:
        writer = csv.DictWriter(file, fieldnames=['login', 'name', 'company', 'location', 'email', 'hireable', 'bio', 'public_repos', 'followers', 'following', 'created_at'])
        writer.writeheader()
        writer.writerows(users)

def save_repos_to_csv(repos):
    with open('repositories.csv', mode='w', newline='') as file:
        writer = csv.DictWriter(file, fieldnames=['login', 'full_name', 'created_at', 'stargazers_count', 'watchers_count', 'language', 'has_projects', 'has_wiki', 'license_name'])
        writer.writeheader()
        writer.writerows(repos)

if __name__ == "__main__":
    users = get_users_in_basel()
    save_users_to_csv(users)

    all_repos = []
    for user in users:
        repos = get_user_repos(user['login'])
        all_repos.extend(repos)

    save_repos_to_csv(all_repos)
    print("Done")
# Out:
# Fetching page 1...
# Fetching page 2...
# Fetching page 3...
# Fetching page 4...
# Fetching page 5...
# Fetching page 6...
# Fetching page 7...
# Fetching page 8...
# Done

# %%
import pandas as pd
repos=pd.read_csv("/content/repositories.csv")

# %%
repos
# Out:
#                     login                                  full_name  \
# 0      ValentineFernandes         ValentineFernandes/Age-Calculator-
# 1      ValentineFernandes                ValentineFernandes/ASP.NET-
# 2      ValentineFernandes          ValentineFernandes/Assignment-4.2
# 3      ValentineFernandes  ValentineFernandes/Bank-Management-System
# 4      ValentineFernandes  ValentineFernandes/BMI-Calculator-Website
# ...                   ...                                        ...
# 35047        krittikaiitb             krittikaiitb/KSP2023-Selection
# 35048        krittikaiitb                     krittikaiitb/SciCompGC
# 35049        krittikaiitb                  krittikaiitb/Scratchboard
# 35050        krittikaiitb                     krittikaiitb/Team-Wiki
# 35051        krittikaiitb                     krittikaiitb/tutorials
#
#                  created_at  stargazers_count  watchers_count  \
# 0      2022-08-17T06:32:19Z                13              13
# 1      2022-04-26T10:12:11Z                18              18
# 2      2022-04-14T11:55:25Z                15              15
# 3      2022-04-24T16:24:17Z                26              26
# 4      2022-08-17T04:47:27Z                11              11
# ...                     ...               ...             ...
# 35047  2023-04-11T05:39:59Z                 0               0
# 35048  2020-02-12T21:25:25Z                 2               2
# 35049  2020-04-05T15:45:32Z                 2               2
# 35050  2020-01-28T13:44:47Z                 1               1
# 35051  2020-04-07T17:19:59Z               166             166
#
#                language  has_projects  has_wiki license_name
# 0                   CSS          True      True          mit
# 1               ASP.NET          True      True          NaN
# 2                  HTML          True      True          NaN
# 3                     C          True      True          NaN
# 4                  HTML          True      True          mit
# ...                 ...           ...       ...          ...
# 35047  Jupyter Notebook          True      True          NaN
# 35048  Jupyter Notebook          True      True          NaN
# 35049  Jupyter Notebook          True      True          NaN
# 35050               NaN          True      True          NaN
# 35051  Jupyter Notebook          True      True          NaN
#
# [35052 rows x 9 columns]

# %%
users=pd.read_csv("/content/users.csv")

# %%
users
# Out:
#                   login                 name                    company  \
# 0    ValentineFernandes  Valentine Fernandes                        NaN
# 1            kovidgoyal          Kovid Goyal                        NaN
# 2             slidenerd            slidenerd                  SLIDENERD
# 3            aryashah2k            Arya Shah                    OPENAOD
# 4         coding-parrot           Gaurav Sen             INTERVIEWREADY
# ..                  ...                  ...                        ...
# 713         mdjawedh022     Md Jawed Hussain               MASAI SCHOOL
# 714       sonusathyadas       Sonu Sathyadas  SYNERGETICS INDIA PVT LTD
# 715            Davekibh        Dave Bhandari                      PH-DC
# 716           vidit0210           Vidit Shah                        NaN
# 717        krittikaiitb             Krittika                        NaN
#
#                 location                      email hireable  \
# 0          Mumbai, India                        NaN      NaN
# 1          Mumbai, India                        NaN      NaN
# 2                 Mumbai        slidenerd@gmail.com     True
# 3          Mumbai, India                        NaN      NaN
# 4          Mumbai, India                        NaN      NaN
# ..                   ...                        ...      ...
# 713  Mumbai, Maharashtra                        NaN      NaN
# 714               Mumbai  sonusathyadas@hotmail.com      NaN
# 715        Mumbai, India  davestephen2002@gmail.com     True
# 716               Mumbai                        NaN      NaN
# 717        Mumbai, India   krittika.club@iitb.ac.in      NaN
#
#                                                    bio  public_repos  \
# 0            HTML |  CSS |  JS  |  SQL |  MYSQL | JAVA            66
# 1             Principal developer of calibre and kitty            37
# 2    Bots, AI, advanced web frameworks, ohlc applic...           113
# 3    Computer Science Major | Machine Learning | So...            88
# 4                                CEO of InterviewReady            11
# ..                                                 ...           ...
# 713  Aspiring full-stack web development profession...            55
# 714  I have 14+ years of corporate training experie...            72
# 715                    Student | Self Taught Developer            62
# 716                                                NaN             8
# 717            We are the Astronomy Club of IIT Bombay             9
#
#      followers  following            created_at  leader_strength
# 0         5248       5275  2022-01-29T08:11:37Z         0.994693
# 1         4277          0  2012-01-06T05:38:24Z      4277.000000
# 2         3167          1  2013-08-01T14:17:19Z      1583.500000
# 3         2595       2580  2020-11-03T03:06:19Z         1.005424
# 4         2412          0  2020-01-03T14:13:35Z      2412.000000
# ..         ...        ...                   ...              ...
# 713         51         17  2022-06-22T06:30:44Z         2.833333
# 714         51          2  2016-05-09T08:21:39Z        17.000000
# 715         51         28  2020-07-02T10:16:17Z         1.758621
# 716         51          1  2014-06-19T19:06:50Z        25.500000
# 717         51          0  2019-12-25T08:15:19Z        51.000000
#
# [718 rows x 12 columns]

# %%
users['hireable']=users['hireable'].fillna(False).astype(bool)
# Out:
# <ipython-input-85-55e76cd2d678>:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   users['hireable']=users['hireable'].fillna(False).astype(bool)

# %%
users
# Out:
#                   login                 name                    company  \
# 0    ValentineFernandes  Valentine Fernandes                        NaN
# 1            kovidgoyal          Kovid Goyal                        NaN
# 2             slidenerd            slidenerd                  SLIDENERD
# 3            aryashah2k            Arya Shah                    OPENAOD
# 4         coding-parrot           Gaurav Sen             INTERVIEWREADY
# ..                  ...                  ...                        ...
# 713         mdjawedh022     Md Jawed Hussain               MASAI SCHOOL
# 714       sonusathyadas       Sonu Sathyadas  SYNERGETICS INDIA PVT LTD
# 715            Davekibh        Dave Bhandari                      PH-DC
# 716           vidit0210           Vidit Shah                        NaN
# 717        krittikaiitb             Krittika                        NaN
#
#                 location                      email  hireable  \
# 0          Mumbai, India                        NaN     False
# 1          Mumbai, India                        NaN     False
# 2                 Mumbai        slidenerd@gmail.com      True
# 3          Mumbai, India                        NaN     False
# 4          Mumbai, India                        NaN     False
# ..                   ...                        ...       ...
# 713  Mumbai, Maharashtra                        NaN     False
# 714               Mumbai  sonusathyadas@hotmail.com     False
# 715        Mumbai, India  davestephen2002@gmail.com      True
# 716               Mumbai                        NaN     False
# 717        Mumbai, India   krittika.club@iitb.ac.in     False
#
#                                                    bio  public_repos  \
# 0            HTML |  CSS |  JS  |  SQL |  MYSQL | JAVA            66
# 1             Principal developer of calibre and kitty            37
# 2    Bots, AI, advanced web frameworks, ohlc applic...           113
# 3    Computer Science Major | Machine Learning | So...            88
# 4                                CEO of InterviewReady            11
# ..                                                 ...           ...
# 713  Aspiring full-stack web development profession...            55
# 714  I have 14+ years of corporate training experie...            72
# 715                    Student | Self Taught Developer            62
# 716                                                NaN             8
# 717            We are the Astronomy Club of IIT Bombay             9
#
#      followers  following            created_at  leader_strength
# 0         5248       5275  2022-01-29T08:11:37Z         0.994693
# 1         4277          0  2012-01-06T05:38:24Z      4277.000000
# 2         3167          1  2013-08-01T14:17:19Z      1583.500000
# 3         2595       2580  2020-11-03T03:06:19Z         1.005424
# 4         2412          0  2020-01-03T14:13:35Z      2412.000000
# ..         ...        ...                   ...              ...
# 713         51         17  2022-06-22T06:30:44Z         2.833333
# 714         51          2  2016-05-09T08:21:39Z        17.000000
# 715         51         28  2020-07-02T10:16:17Z         1.758621
# 716         51          1  2014-06-19T19:06:50Z        25.500000
# 717         51          0  2019-12-25T08:15:19Z        51.000000
#
# [718 rows x 12 columns]

# %%
users = users.fillna("").astype(str)
repos = repos.fillna("").astype(str)

# %%
users
# Out:
#                   login                 name                    company  \
# 0    ValentineFernandes  Valentine Fernandes
# 1            kovidgoyal          Kovid Goyal
# 2             slidenerd            slidenerd                  SLIDENERD
# 3            aryashah2k            Arya Shah                    OPENAOD
# 4         coding-parrot           Gaurav Sen             INTERVIEWREADY
# ..                  ...                  ...                        ...
# 713         mdjawedh022     Md Jawed Hussain               MASAI SCHOOL
# 714       sonusathyadas       Sonu Sathyadas  SYNERGETICS INDIA PVT LTD
# 715            Davekibh        Dave Bhandari                      PH-DC
# 716           vidit0210           Vidit Shah
# 717        krittikaiitb             Krittika
#
#                 location                      email hireable  \
# 0          Mumbai, India                               False
# 1          Mumbai, India                               False
# 2                 Mumbai        slidenerd@gmail.com     True
# 3          Mumbai, India                               False
# 4          Mumbai, India                               False
# ..                   ...                        ...      ...
# 713  Mumbai, Maharashtra                               False
# 714               Mumbai  sonusathyadas@hotmail.com    False
# 715        Mumbai, India  davestephen2002@gmail.com     True
# 716               Mumbai                               False
# 717        Mumbai, India   krittika.club@iitb.ac.in    False
#
#                                                    bio public_repos followers  \
# 0            HTML |  CSS |  JS  |  SQL |  MYSQL | JAVA           66      5248
# 1             Principal developer of calibre and kitty           37      4277
# 2    Bots, AI, advanced web frameworks, ohlc applic...          113      3167
# 3    Computer Science Major | Machine Learning | So...           88      2595
# 4                                CEO of InterviewReady           11      2412
# ..                                                 ...          ...       ...
# 713  Aspiring full-stack web development profession...           55        51
# 714  I have 14+ years of corporate training experie...           72        51
# 715                    Student | Self Taught Developer           62        51
# 716                                                               8        51
# 717            We are the Astronomy Club of IIT Bombay            9        51
#
#     following            created_at     leader_strength
# 0        5275  2022-01-29T08:11:37Z  0.9946929492039424
# 1           0  2012-01-06T05:38:24Z              4277.0
# 2           1  2013-08-01T14:17:19Z              1583.5
# 3        2580  2020-11-03T03:06:19Z  1.0054242541650522
# 4           0  2020-01-03T14:13:35Z              2412.0
# ..        ...                   ...                 ...
# 713        17  2022-06-22T06:30:44Z   2.833333333333333
# 714         2  2016-05-09T08:21:39Z                17.0
# 715        28  2020-07-02T10:16:17Z  1.7586206896551724
# 716         1  2014-06-19T19:06:50Z                25.5
# 717         0  2019-12-25T08:15:19Z                51.0
#
# [718 rows x 12 columns]

# %%
repos
# Out:
#                     login                                  full_name  \
# 0      ValentineFernandes         ValentineFernandes/Age-Calculator-
# 1      ValentineFernandes                ValentineFernandes/ASP.NET-
# 2      ValentineFernandes          ValentineFernandes/Assignment-4.2
# 3      ValentineFernandes  ValentineFernandes/Bank-Management-System
# 4      ValentineFernandes  ValentineFernandes/BMI-Calculator-Website
# ...                   ...                                        ...
# 35047        krittikaiitb             krittikaiitb/KSP2023-Selection
# 35048        krittikaiitb                     krittikaiitb/SciCompGC
# 35049        krittikaiitb                  krittikaiitb/Scratchboard
# 35050        krittikaiitb                     krittikaiitb/Team-Wiki
# 35051        krittikaiitb                     krittikaiitb/tutorials
#
#                  created_at stargazers_count watchers_count          language  \
# 0      2022-08-17T06:32:19Z               13             13               CSS
# 1      2022-04-26T10:12:11Z               18             18           ASP.NET
# 2      2022-04-14T11:55:25Z               15             15              HTML
# 3      2022-04-24T16:24:17Z               26             26                 C
# 4      2022-08-17T04:47:27Z               11             11              HTML
# ...                     ...              ...            ...               ...
# 35047  2023-04-11T05:39:59Z                0              0  Jupyter Notebook
# 35048  2020-02-12T21:25:25Z                2              2  Jupyter Notebook
# 35049  2020-04-05T15:45:32Z                2              2  Jupyter Notebook
# 35050  2020-01-28T13:44:47Z                1              1
# 35051  2020-04-07T17:19:59Z              166            166  Jupyter Notebook
#
#       has_projects has_wiki license_name
# 0             True     True          mit
# 1             True     True
# 2             True     True
# 3             True     True
# 4             True     True          mit
# ...            ...      ...          ...
# 35047         True     True
# 35048         True     True
# 35049         True     True
# 35050         True     True
# 35051         True     True
#
# [35052 rows x 9 columns]

# %%
repos['has_wiki'] = repos['has_wiki'].astype(str).replace({'True': 'true', 'False': 'false'})
repos['has_projects'] = repos['has_projects'].astype(str).replace({'True': 'true', 'False': 'false'})

# %%
repos
# Out:
#                     login                                  full_name  \
# 0      ValentineFernandes         ValentineFernandes/Age-Calculator-
# 1      ValentineFernandes                ValentineFernandes/ASP.NET-
# 2      ValentineFernandes          ValentineFernandes/Assignment-4.2
# 3      ValentineFernandes  ValentineFernandes/Bank-Management-System
# 4      ValentineFernandes  ValentineFernandes/BMI-Calculator-Website
# ...                   ...                                        ...
# 35047        krittikaiitb             krittikaiitb/KSP2023-Selection
# 35048        krittikaiitb                     krittikaiitb/SciCompGC
# 35049        krittikaiitb                  krittikaiitb/Scratchboard
# 35050        krittikaiitb                     krittikaiitb/Team-Wiki
# 35051        krittikaiitb                     krittikaiitb/tutorials
#
#                  created_at stargazers_count watchers_count          language  \
# 0      2022-08-17T06:32:19Z               13             13               CSS
# 1      2022-04-26T10:12:11Z               18             18           ASP.NET
# 2      2022-04-14T11:55:25Z               15             15              HTML
# 3      2022-04-24T16:24:17Z               26             26                 C
# 4      2022-08-17T04:47:27Z               11             11              HTML
# ...                     ...              ...            ...               ...
# 35047  2023-04-11T05:39:59Z                0              0  Jupyter Notebook
# 35048  2020-02-12T21:25:25Z                2              2  Jupyter Notebook
# 35049  2020-04-05T15:45:32Z                2              2  Jupyter Notebook
# 35050  2020-01-28T13:44:47Z                1              1
# 35051  2020-04-07T17:19:59Z              166            166  Jupyter Notebook
#
#       has_projects has_wiki license_name
# 0             true     true          mit
# 1             true     true
# 2             true     true
# 3             true     true
# 4             true     true          mit
# ...            ...      ...          ...
# 35047         true     true
# 35048         true     true
# 35049         true     true
# 35050         true     true
# 35051         true     true
#
# [35052 rows x 9 columns]

# %%
users.to_csv('users1.csv', index=False)
repos.to_csv('repos1.csv', index=False)

# %%
repos1=pd.read_csv("/content/repos1.csv")
repos1
# Out:
#                     login                                  full_name  \
# 0      ValentineFernandes         ValentineFernandes/Age-Calculator-
# 1      ValentineFernandes                ValentineFernandes/ASP.NET-
# 2      ValentineFernandes          ValentineFernandes/Assignment-4.2
# 3      ValentineFernandes  ValentineFernandes/Bank-Management-System
# 4      ValentineFernandes  ValentineFernandes/BMI-Calculator-Website
# ...                   ...                                        ...
# 35047        krittikaiitb             krittikaiitb/KSP2023-Selection
# 35048        krittikaiitb                     krittikaiitb/SciCompGC
# 35049        krittikaiitb                  krittikaiitb/Scratchboard
# 35050        krittikaiitb                     krittikaiitb/Team-Wiki
# 35051        krittikaiitb                     krittikaiitb/tutorials
#
#                  created_at  stargazers_count  watchers_count  \
# 0      2022-08-17T06:32:19Z                13              13
# 1      2022-04-26T10:12:11Z                18              18
# 2      2022-04-14T11:55:25Z                15              15
# 3      2022-04-24T16:24:17Z                26              26
# 4      2022-08-17T04:47:27Z                11              11
# ...                     ...               ...             ...
# 35047  2023-04-11T05:39:59Z                 0               0
# 35048  2020-02-12T21:25:25Z                 2               2
# 35049  2020-04-05T15:45:32Z                 2               2
# 35050  2020-01-28T13:44:47Z                 1               1
# 35051  2020-04-07T17:19:59Z               166             166
#
#                language  has_projects  has_wiki license_name
# 0                   CSS          True      True          mit
# 1               ASP.NET          True      True          NaN
# 2                  HTML          True      True          NaN
# 3                     C          True      True          NaN
# 4                  HTML          True      True          mit
# ...                 ...           ...       ...          ...
# 35047  Jupyter Notebook          True      True          NaN
# 35048  Jupyter Notebook          True      True          NaN
# 35049  Jupyter Notebook          True      True          NaN
# 35050               NaN          True      True          NaN
# 35051  Jupyter Notebook          True      True          NaN
#
# [35052 rows x 9 columns]

# %% [markdown]
# Q1)Who are the top 5 users in Mumbai with the highest number of followers? List their login in order, comma-separated.

# %%
users.sort_values(by='followers',ascending=False).head(5)
# Out:
#                 login                 name         company       location  \
# 0  ValentineFernandes  Valentine Fernandes             NaN  Mumbai, India
# 1          kovidgoyal          Kovid Goyal             NaN  Mumbai, India
# 2           slidenerd            slidenerd       SLIDENERD         Mumbai
# 3          aryashah2k            Arya Shah         OPENAOD  Mumbai, India
# 4       coding-parrot           Gaurav Sen  INTERVIEWREADY  Mumbai, India
#
#                  email hireable  \
# 0                  NaN      NaN
# 1                  NaN      NaN
# 2  slidenerd@gmail.com     True
# 3                  NaN      NaN
# 4                  NaN      NaN
#
#                                                  bio  public_repos  followers  \
# 0          HTML |  CSS |  JS  |  SQL |  MYSQL | JAVA            66       5248
# 1           Principal developer of calibre and kitty            37       4277
# 2  Bots, AI, advanced web frameworks, ohlc applic...           113       3167
# 3  Computer Science Major | Machine Learning | So...            88       2595
# 4                              CEO of InterviewReady            11       2412
#
#    following            created_at
# 0       5275  2022-01-29T08:11:37Z
# 1          0  2012-01-06T05:38:24Z
# 2          1  2013-08-01T14:17:19Z
# 3       2580  2020-11-03T03:06:19Z
# 4          0  2020-01-03T14:13:35Z

# %%
users.sort_values(by='followers',ascending=False).head(5)['login'].to_list()
# Out:
# ['ValentineFernandes',
#  'kovidgoyal',
#  'slidenerd',
#  'aryashah2k',
#  'coding-parrot']

# %% [markdown]
# Q2)Who are the 5 earliest registered GitHub users in Mumbai? List their login in ascending order of created_at, comma-separated.
# Users

# %%
users.sort_values(by='created_at',ascending=True).head(5)
# Out:
#              login            name                             company  \
# 599          ivank      Ivan Kerin                       FLUENT HEALTH
# 453  sandeepshetty  Sandeep Shetty  SIMPTHINGS (HTTP://SIMPTHINGS.COM)
# 711            svs       Siddharth                                 NaN
# 312   nitinhayaran   Nitin Hayaran                         CAMPUSKUDOS
# 650        nischal  Nischal Shetty                        CODIGAMI INC
#
#           location                     email hireable  \
# 599  India, Mumbai          ikerin@gmail.com      NaN
# 453  Mumbai, India  sandeep.shetty@gmail.com     True
# 711         Mumbai                svs@svs.io     True
# 312  Mumbai, India    nitinhayaran@gmail.com     True
# 650  Mumbai, India                       NaN      NaN
#
#                                                    bio  public_repos  \
# 599                                  ok at programming            54
# 453                                                NaN             9
# 711                                                NaN            76
# 312                                                NaN            39
# 650  Founder, CEO WazirX & Crowdfire. WazirX is Ind...             1
#
#      followers  following            created_at
# 599         58          6  2008-04-04T08:04:42Z
# 453         72         18  2008-08-13T06:32:17Z
# 711         51         11  2009-01-12T11:12:30Z
# 312         93         56  2009-01-30T17:33:35Z
# 650         54          5  2009-02-03T14:40:02Z

# %%
users.sort_values(by='created_at',ascending=True).head(5)['login'].to_list()
# Out:
# ['ivank', 'sandeepshetty', 'svs', 'nitinhayaran', 'nischal']

# %% [markdown]
# Q3)What are the 3 most popular license among these users? Ignore missing licenses. List the license_name in order, comma-separated.

# %%
resp['license_name'].value_counts().head(3)
# Out:
# license_name
# mit           6405
# apache-2.0    1625
# other         1370
# Name: count, dtype: int64

# %% [markdown]
# Q4)Which company do the majority of these developers work at?
# Company (cleaned up as explained above)

# %%
users['company'].value_counts()
# Out:
# company
# MASAI SCHOOL                                         14
# BROWSERSTACK                                         13
# FRAPPE                                               10
# IIT BOMBAY                                            9
# ITM SKILLS UNIVERSITY                                 6
#                                                      ..
# OPEN-XYZ                                              1
# MYULOGIC SOLUTIONS                                    1
# VEERMATA JIJABAI TECHNOLOGICAL INSTITUTE              1
# AUTOCODEAPP @REDEMPTIONER @NSSUCOE @INTUITIONEERS     1
# PH-DC                                                 1
# Name: count, Length: 337, dtype: int64

# %% [markdown]
# Q5)Which programming language is most popular among these users?

# %%
resp['language'].value_counts()
# Out:
# language
# JavaScript          6944
# Python              3820
# HTML                2631
# Jupyter Notebook    1951
# Java                1895
#                     ...
# Cairo                  1
# Cython                 1
# RAML                   1
# Visual Basic           1
# Liquid                 1
# Name: count, Length: 133, dtype: int64

# %% [markdown]
# Q6) Which programming language is the second most popular among users who joined after 2020?

# %%
resp[resp['created_at'] > '2020-12-31']['language'].value_counts()
# Out:
# language
# JavaScript          4415
# HTML                1592
# Python              1590
# TypeScript          1131
# Jupyter Notebook    1030
#                     ...
# Cython                 1
# Cairo                  1
# Starlark               1
# CoffeeScript           1
# Liquid                 1
# Name: count, Length: 93, dtype: int64

# %% [markdown]
# Q7) Which language has the highest average number of stars per repository?

# %%
resp.groupby('language')['stargazers_count'].mean().sort_values(ascending=False)
# Out:
# language
# TSQL                       740.500000
# C#                          50.979381
# Swift                       32.979730
# Matlab                      26.466667
# Objective-C                 21.431452
#                               ...
# Gleam                        0.000000
# GCC Machine Description      0.000000
# SQLPL                        0.000000
# GAP                          0.000000
# ANTLR                        0.000000
# Name: stargazers_count, Length: 133, dtype: float64

# %% [markdown]
# Q8) Let's define leader_strength as followers / (1 + following). Who are the top 5 in terms of leader_strength? List their login in order, comma-separated.

# %%
users['leader_strength']=users['followers']/(1+users['following'])

# %%
users.sort_values(by='leader_strength',ascending=False).head(5)['login'].to_list()
# Out:
# ['kovidgoyal', 'coding-parrot', 'gkcs', 'slidenerd', 'dmalvia']

# %% [markdown]
# Q9)What is the correlation between the number of followers and the number of public repositories among users in Mumbai?
# Correlation between followers and repos (to 3 decimal places, e.g. 0.123 or -0.123)

# %%
users['followers'].corr(users['public_repos'])
# Out:
# 0.03463767549833904

# %% [markdown]
# Q10)Does creating more repos help users get more followers? Using regression, estimate how many additional followers a user gets per additional public repository.
# Regression slope of followers on repos (to 3 decimal places, e.g. 0.123 or -0.123)

# %%
# prompt: Regression slope of followers on repos

import numpy as np

# Assuming 'users' DataFrame is already loaded and processed as in the original code.

# Calculate the regression slope of followers on repos
slope, intercept = np.polyfit(users['public_repos'].astype(int), users['followers'].astype(int), 1)

print(f"{slope:.3f}")
# Out:
# 0.101

# %% [markdown]
# Q11)Do people typically enable projects and wikis together? What is the correlation between a repo having projects enabled and having wiki enabled?
# Correlation between projects and wiki enabled (to 3 decimal places, e.g. 0.123 or -0.123)

# %%
if repos['has_projects'].dtype == 'object':
    repos['has_projects'] = repos['has_projects'].map({'true': True, 'false': False})
if repos['has_wiki'].dtype == 'object':
    repos['has_wiki'] = repos['has_wiki'].map({'true': True, 'false': False})

correlation = repos['has_projects'].corr(repos['has_wiki'])

print(round(correlation, 3))
# Out:
# 0.171

# %% [markdown]
# Q12) Do hireable users follow more people than those who are not hireable?
# Average of following per user for hireable=true minus the average following for the rest (to 3 decimal places, e.g. 12.345 or -12.345)

# %%
hireable_avg_following = users[users['hireable'] == True]['following'].mean()
non_hireable_avg_following = users[users['hireable'] == False]['following'].mean()
difference = hireable_avg_following - non_hireable_avg_following
difference
# Out:
# nan

# %% [markdown]
# Q13)Some developers write long bios. Does that help them get more followers? What's the correlation of the length of their bio (in Unicode words, split by whitespace) with followers? (Ignore people without bios)
# Regression slope of followers on bio word count (to 3 decimal places, e.g. 12.345 or -12.345)

# %%
import pandas as pd
import statsmodels.api as sm

# Load the CSV file
csv_file = 'users.csv'  # Ensure this path is correct

# Load the CSV into a DataFrame
df = pd.read_csv(csv_file)

# Check the first few rows and the data types of the DataFrame
print("DataFrame Overview:")
print(df.head())
print("\nDataFrame Info:")
print(df.info())

# Filter out users without bios
df = df[df['bio'].notnull()]

# Calculate the length of each bio in words
df['bio_word_count'] = df['bio'].str.split().str.len()

# Prepare the independent variable (X) and dependent variable (y)
X = df['bio_word_count']
y = df['followers']  # Adjust the column name as per your dataset

# Add a constant to the independent variable (for the intercept)
X = sm.add_constant(X)

# Fit the regression model
model = sm.OLS(y, X).fit()

# Get the slope (coefficient of the bio_word_count)
slope = model.params['bio_word_count']

# Print the regression slope rounded to three decimal places
print(f"\nRegression slope of followers on bio word count: {slope:.3f}")
# Out:
# DataFrame Overview:
#                 login                 name         company       location  \
# 0  ValentineFernandes  Valentine Fernandes             NaN  Mumbai, India
# 1          kovidgoyal          Kovid Goyal             NaN  Mumbai, India
# 2           slidenerd            slidenerd       SLIDENERD         Mumbai
# 3          aryashah2k            Arya Shah         OPENAOD  Mumbai, India
# 4       coding-parrot           Gaurav Sen  INTERVIEWREADY  Mumbai, India
#
#                  email  hireable  \
# 0                  NaN     False
# 1                  NaN     False
# 2  slidenerd@gmail.com      True
# 3                  NaN     False
# 4                  NaN     False
#
#                                                  bio  public_repos  followers  \
# 0          HTML |  CSS |  JS  |  SQL |  MYSQL | JAVA            66       5248
# 1           Principal developer of calibre and kitty            37       4277
# 2  Bots, AI, advanced web frameworks, ohlc applic...           113       3167
# 3  Computer Science Major | Machine Learning | So...            88       2595
# 4                              CEO of InterviewReady            11       2412
#
#    following                 created_at  leader_strength
# 0       5275  2022-01-29 08:11:37+00:00         0.994693
# 1          0  2012-01-06 05:38:24+00:00      4277.000000
# 2          1  2013-08-01 14:17:19+00:00      1583.500000
# 3       2580  2020-11-03 03:06:19+00:00         1.005424
# 4          0  2020-01-03 14:13:35+00:00      2412.000000
#
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 718 entries, 0 to 717
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   login            718 non-null    object
#  1   name             710 non-null    object
#  2   company          405 non-null    object
#  3   location         718 non-null    object
#  4   email            330 non-null    object
#  5   hireable         718 non-null    bool
#  6   bio              627 non-null    object
#  7   public_repos     718 non-null    int64
#  8   followers        718 non-null    int64
#  9   following        718 non-null    int64
#  10  created_at       718 non-null    object
#  11  leader_strength  718 non-null    float64
# dtypes: bool(1), float64(1), int64(3), object(7)
# memory usage: 62.5+ KB
# None
#
# Regression slope of followers on bio word count: -0.191
# <ipython-input-2-2d0cbe58dc40>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['bio_word_count'] = df['bio'].str.split().str.len()

# %%
#Q13
import pandas as pd
import statsmodels.api as sm

# Load the users data from the CSV file
users_df = pd.read_csv('users.csv')

# Filter out users without bios
users_with_bios = users_df[users_df['bio'].notna()]

# Calculate the length of the bio in words
#users_with_bios['bio_word_count'] = users_with_bios['bio'].str.split(" ").str.len()

users_with_bios['bio_word_count'] = users_with_bio['bio'].apply(lambda x: len(x.split()))


# Prepare the data for regression
X = users_with_bios['bio_word_count']  # Independent variable
y = users_with_bios['followers']        # Dependent variable

# Add a constant to the independent variable for the regression
X = sm.add_constant(X)

# Fit the regression model
model = sm.OLS(y, X).fit()

# Get the regression slope (coefficient for bio_word_count)
slope = model.params['bio_word_count']

# Print the slope rounded to three decimal places
print(f'Regression slope of followers on bio word count: {slope:.3f}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-187113772ce8> in <cell line: 14>()
#      12 #users_with_bios['bio_word_count'] = users_with_bios['bio'].str.split(" ").str.len()
#      13
# ---> 14 users_with_bios['bio_word_count'] = users_with_bio['bio'].apply(lambda x: len(x.split()))
#      15
#      16
#
# NameError: name 'users_with_bio' is not defined

# %% [markdown]
# Q14Who created the most repositories on weekends (UTC)? List the top 5 users' login in order, comma-separated
# Users login

# %%
# prompt: Who created the most repositories on weekends (UTC)? List the top 5 users' login in order, comma-separated Users login

import pandas as pd

# Assuming 'resp' DataFrame (repositories data) is already loaded and processed

# Convert 'created_at' column to datetime objects
resp['created_at'] = pd.to_datetime(resp['created_at'])

# Extract the day of the week (0 = Monday, 6 = Sunday)
resp['day_of_week'] = resp['created_at'].dt.dayofweek

# Identify weekend repositories (Saturday and Sunday)
weekend_repos = resp[resp['day_of_week'].isin([5, 6])]

# Count repositories created by each user on weekends
weekend_repo_counts = weekend_repos.groupby('login')['full_name'].count()

# Get the top 5 users
top_5_users = weekend_repo_counts.nlargest(5).index.tolist()

# Print the result (comma-separated user logins)
print(','.join(top_5_users))
# Out:
# backtrackbaba,devdatta95,Kushal334,ankit0183,burhanuday

# %% [markdown]
# Q15)Do people who are hireable share their email addresses more often?
# [fraction of users with email when hireable=true] minus [fraction of users with email for the rest] (to 3 decimal places, e.g. 0.123 or -0.123)

# %%
# prompt: Do people who are hireable share their email addresses more often? [fraction of users with email when hireable=true] minus [fraction of users with email for the rest] (to 3 decimal places, e.g. 0.123 or -0.123)

# Calculate the fraction of users with email when hireable=True
hireable_with_email = len(users[(users['hireable'] == 'True') & (users['email'] != '')])
total_hireable = len(users[users['hireable'] == 'True'])
fraction_hireable_email = hireable_with_email / total_hireable if total_hireable > 0 else 0

# Calculate the fraction of users with email when hireable=False or NaN
non_hireable_with_email = len(users[(users['hireable'] == 'False') & (users['email'] != '')])
total_non_hireable = len(users[users['hireable'] == 'False'])
fraction_non_hireable_email = non_hireable_with_email / total_non_hireable if total_non_hireable > 0 else 0


difference = fraction_hireable_email - fraction_non_hireable_email
print(f"{difference:.3f}")
# Out:
# 0.596

# %%
fraction_hierable = users[users['hireable'] == True]['email'].notna().mean()
fraction_non_hierable = users[users['hireable'] == False]['email'].notna().mean()
diff = fraction_hierable - fraction_non_hierable
diff
# Out:
# nan

# %% [markdown]
# Q16Let's assume that the last word in a user's name is their surname (ignore missing names, trim and split by whitespace.) What's the most common surname? (If there's a tie, list them all, comma-separated, alphabetically)
# Number of users with the most common surname

# %%
new_users = users[users['name'].notna()].copy()
new_users['surname'] = new_users['name'].str.split().str[-1].str.strip()
surname_counts = new_users['surname'].value_counts()
max_count = surname_counts.max()
common_surnames = surname_counts[surname_counts == max_count].index.tolist()
common_surnames.sort()
print(','.join(common_surnames))
# Out:
# Singh

# %%
USERS=pd.read_csv("/content/users1.csv")
USERS
# Out:
#                login                name           company  \
# 0            IDouble            Alp ₿📈🚀🌕  IDEX/USD @IDEXIO
# 1    TheOfficialFloW         Andy Nguyen               NaN
# 2            Seldaek      Jordi Boggiano         PACKAGIST
# 3              riscv              RISC-V               NaN
# 4        JonnyBurger        Jonny Burger      REMOTION-DEV
# ..               ...                 ...               ...
# 467        yenicelik               David        ETH ZURICH
# 468         algattik  Alexandre Gattiker         MICROSOFT
# 469         lukstafi    Lukasz Stafiniak               NaN
# 470             vxsx        Vadim Sikora             DIVIO
# 471         panterch       Beat Seeliger         PANTER AG
#
#                         location                          email  hireable  \
# 0            Zurich, Switzerland                            NaN     False
# 1                         Zurich  theofficialflow1996@gmail.com     False
# 2    Zürich, Zurich, Switzerland             j.boggiano@seld.be     False
# 3                     Zurich, CH                 info@riscv.org     False
# 4            Zurich, Switzerland                    hi@jonny.io     False
# ..                           ...                            ...       ...
# 467          Zurich, Switzerland                            NaN     False
# 468          Zurich, Switzerland                            NaN     False
# 469                       Zurich             lukstafi@gmail.com      True
# 470                       Zurich         vadim.sikora@gmail.com     False
# 471                       Zurich                            NaN     False
#
#                                                    bio  public_repos  \
# 0    🗽 Be greedy when others are fearful and be fea...            61
# 1                        Information Security Engineer            39
# 2    \r\n    Working on https://packagist.com and h...           259
# 3       The Open-Standard Instruction Set Architecture            58
# 4                   Creative hacker @remotion-dev \r\n           238
# ..                                                 ...           ...
# 467                                                NaN            53
# 468  I'm a software engineer at Microsoft working w...            82
# 469                                                NaN            22
# 470                                        Boring guy.           110
# 471                                it's fun to compute            58
#
#      followers  following                 created_at  leader_strength
# 0        32344     316253  2016-03-31 09:16:13+00:00         0.102272
# 1         4595         32  2015-09-12 08:16:45+00:00       139.242424
# 2         4559          1  2010-01-16 18:28:47+00:00      2279.500000
# 3         3157          0  2015-02-05 21:49:09+00:00      3157.000000
# 4         2462         30  2012-04-10 14:57:36+00:00        79.419355
# ..         ...        ...                        ...              ...
# 467         52         42  2014-09-28 09:22:04+00:00         1.209302
# 468         52          0  2016-09-09 13:31:39+00:00        52.000000
# 469         51        132  2012-12-20 15:02:18+00:00         0.383459
# 470         51         15  2010-08-17 05:26:11+00:00         3.187500
# 471         51          9  2008-06-26 12:45:14+00:00         5.100000
#
# [472 rows x 12 columns]
